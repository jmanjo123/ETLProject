# %%
import gzip
import csv
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
sns.set_style("whitegrid")
sns.set(font_scale=1.5)

# %%
# NY Listing -> GZfile
ny_path_listings = "C:/Users/maria/Desktop/DATA SCIENCE BOOTCAMP/PROJECTS/Project 2_Group-4/Resources/NewYork_Listings.csv.gz"
new_york_listings = pd.read_csv(ny_path, nrows=100, compression='gzip',
                   error_bad_lines=False)
new_york_listings.head()
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0  2595  https://www.airbnb.com/rooms/2595  20191204162729   2019-12-07
# 1  3831  https://www.airbnb.com/rooms/3831  20191204162729   2019-12-07
# 2  5099  https://www.airbnb.com/rooms/5099  20191204162729   2019-12-06
# 3  5121  https://www.airbnb.com/rooms/5121  20191204162729   2019-12-06
# 4  5178  https://www.airbnb.com/rooms/5178  20191204162729   2019-12-05
#
#                                         name  \
# 0                      Skylit Midtown Castle
# 1            Cozy Entire Floor of Brownstone
# 2  Large Cozy 1 BR Apartment In Midtown East
# 3                            BlissArtsSpace!
# 4           Large Furnished Room Near B'way
#
#                                              summary  \
# 0  Beautiful, spacious skylit studio in the heart...
# 1  Urban retreat: enjoy 500 s.f. floor in 1899 br...
# 2  My large 1 bedroom apartment has a true New Yo...
# ...

# %%
# NY Reviws -> GZfile
ny_path_reviews = "C:/Users/maria/Desktop/DATA SCIENCE BOOTCAMP/PROJECTS/Project 2_Group-4/Resources/reviews.csv.gz"
new_york_reviews = pd.read_csv(ny_path, nrows=100, compression='gzip',
                   error_bad_lines=False)
new_york_reviews.head()
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0  2595  https://www.airbnb.com/rooms/2595  20191204162729   2019-12-07
# 1  3831  https://www.airbnb.com/rooms/3831  20191204162729   2019-12-07
# 2  5099  https://www.airbnb.com/rooms/5099  20191204162729   2019-12-06
# 3  5121  https://www.airbnb.com/rooms/5121  20191204162729   2019-12-06
# 4  5178  https://www.airbnb.com/rooms/5178  20191204162729   2019-12-05
#
#                                         name  \
# 0                      Skylit Midtown Castle
# 1            Cozy Entire Floor of Brownstone
# 2  Large Cozy 1 BR Apartment In Midtown East
# 3                            BlissArtsSpace!
# 4           Large Furnished Room Near B'way
#
#                                              summary  \
# 0  Beautiful, spacious skylit studio in the heart...
# 1  Urban retreat: enjoy 500 s.f. floor in 1899 br...
# 2  My large 1 bedroom apartment has a true New Yo...
# ...

# %%
# NY Neighboardhoods -> GZfile

# %%
# NY Listings
listing_NY_path = "C:/Users/maria/Desktop/DATA SCIENCE BOOTCAMP/PROJECTS/Project 2_Group-4/Resources/listings_NY.csv"
ny_listings = pd.read_csv(listing_NY_path)
ny_listings.head()
# Out:
#      id                                       name  host_id    host_name  \
# 0  2595                      Skylit Midtown Castle     2845     Jennifer
# 1  3831            Cozy Entire Floor of Brownstone     4869  LisaRoxanne
# 2  5099  Large Cozy 1 BR Apartment In Midtown East     7322        Chris
# 3  5121                            BlissArtsSpace!     7356        Garon
# 4  5178           Large Furnished Room Near B'way      8967     Shunichi
#
#   neighbourhood_group       neighbourhood  latitude  longitude  \
# 0           Manhattan             Midtown  40.75362  -73.98377
# 1            Brooklyn        Clinton Hill  40.68514  -73.95976
# 2           Manhattan         Murray Hill  40.74767  -73.97500
# 3            Brooklyn  Bedford-Stuyvesant  40.68688  -73.95596
# 4           Manhattan      Hell's Kitchen  40.76489  -73.98493
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
# NY reviews
reviews_NY_path = "C:/Users/maria/Desktop/DATA SCIENCE BOOTCAMP/PROJECTS/Project 2_Group-4/Resources/reviews_NY.csv"
ny_reviews = pd.read_csv(reviews_NY_path)
ny_reviews.head()
# Out:
#    listing_id        date
# 0        2595  2009-11-21
# 1        2595  2009-12-05
# 2        2595  2009-12-10
# 3        2595  2010-04-09
# 4        2595  2010-05-25

# %%
# NY neighbourhoods
neighbourhoods_NY_path = "C:/Users/maria/Desktop/DATA SCIENCE BOOTCAMP/PROJECTS/Project 2_Group-4/Resources/neighbourhoods_NY.csv"
ny_neighbourhoods = pd.read_csv(neighbourhoods_NY_path)
ny_neighbourhoods.head()
# Out:
#   neighbourhood_group neighbourhood
# 0               Bronx      Allerton
# 1               Bronx    Baychester
# 2               Bronx       Belmont
# 3               Bronx     Bronxdale
# 4               Bronx   Castle Hill

# %%
ny_listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50599 entries, 0 to 50598
# Data columns (total 16 columns):
# id                                50599 non-null int64
# name                              50582 non-null object
# host_id                           50599 non-null int64
# host_name                         50036 non-null object
# neighbourhood_group               50599 non-null object
# neighbourhood                     50599 non-null object
# latitude                          50599 non-null float64
# longitude                         50599 non-null float64
# room_type                         50599 non-null object
# price                             50599 non-null int64
# minimum_nights                    50599 non-null int64
# number_of_reviews                 50599 non-null int64
# last_review                       40379 non-null object
# reviews_per_month                 40379 non-null float64
# calculated_host_listings_count    50599 non-null int64
# ...

# %%
# Looking for Null Values
ny_listings.isnull().sum()
# Out:
# id                                    0
# name                                 17
# host_id                               0
# host_name                           563
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10220
# reviews_per_month                 10220
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
# Visualizing the distribution for every "feature"
features = ny_listings.hist(edgecolor="black", linewidth=1.2, figsize=(30, 30))

# %%
plt.figure(figsize=(100, 100))
sns.pairplot(ny_listings, height=3, diag_kind="hist")
# Out:
# C:\Users\maria\Anaconda3\lib\site-packages\numpy\lib\histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\maria\Anaconda3\lib\site-packages\numpy\lib\histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
sns.catplot("neighbourhood_group", data=ny_listings, kind="count", height=8)

# %%
sns.set(font_scale=1.5)
sns.catplot("room_type", data=ny_listings, kind="count", height=8)

# %%
plt.style.use("fivethirtyeight")

data = ny_listings.neighbourhood.value_counts()[:10]
plt.figure(figsize=(20, 8))
x = list(data.index)
y = list(data.values)
x.reverse()
y.reverse()

plt.title("Most Popular Neighbourhood")
plt.ylabel("Neighbourhood Area")
plt.xlabel("Number of guest Who host in this Area")

plt.barh(x, y)
# Out:
# <BarContainer object of 10 artists>

# %%
plt.figure(figsize=(12, 8))
plt.scatter(ny_listings.longitude, ny_listings.latitude, c=ny_listings.availability_365, cmap='summer', edgecolor='black', linewidth=1, alpha=0.75)

cbar = plt.colorbar()
cbar.set_label('availability_365')

# %%
print(f"Average of price per night : ${ny_listings.price.mean():.2f}")
print(f"Maximum price per night : ${ny_listings.price.max()}")
print(f"Minimum price per night : ${ny_listings.price.min()}")
# Out:
# Average of price per night : $158.17
# Maximum price per night : $10000
# Minimum price per night : $0

# %%
# "Free houses"
ny_listings[ny_listings.price == 0]
# Out:
#              id                                               name    host_id  \
# 21519  18750597  Huge Brooklyn Brownstone Living, Close to it all.    8993084
# 23802  20523843    MARTIAL LOFT 3: REDEMPTION (upstairs, 2nd room)   15787004
# 23911  20608117                    Sunny, Quiet Room in Greenpoint    1641537
# 23936  20624541      Modern apartment in the heart of Williamsburg   10132166
# 23953  20639628  Spacious comfortable master bedroom with nice ...   86327101
# 23954  20639792  Contemporary bedroom in brownstone with nice view   86327101
# 23955  20639914       Cozy yet spacious private brownstone bedroom   86327101
# 24371  20933849                              the best you can find   13709292
# 24908  21291569  Coliving in Brooklyn! Modern design / Shared room  101970559
# 24932  21304320             Best Coliving space ever! Shared room.  101970559
# 48338  39722994               @@@@ Bryant Park 2 Bedrooms NYC @@@@   17655093
# ...

# %%
# correlation matrix
sns.set(font_scale=3)
plt.figure(figsize=(30, 20))
sns.heatmap(ny_listings.corr(), annot=True)
