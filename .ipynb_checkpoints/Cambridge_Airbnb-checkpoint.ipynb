# %% [markdown]
# ## Table Of Contents
#
#
# - [Store CSV into DataFrame](#Store-CSV-into-DataFrame)
# - [Data Exploration](#Data-Exploration)
# - [Data Clean-Up Process](#New-Data-With-Selected-Columns)
# - [Database Process](#Database-Process)
# - [Queries](#Queries)
#
#
#   ### [Project Report](https://docs.google.com/document/d/1qSFce4Ubi3k_l5FdNinCG_Jhylltwt4KJD3ewPj3d9c/edit?usp=sharing)

# %% [markdown]
# ### Libraries

# %%
import pandas as pd
from sqlalchemy import create_engine
import psycopg2
from config import password

# %% [markdown]
# ### Store CSV into DataFrame

# %%
# Cambridge Listing --> CSV file
cambridge_path_listings = "../ETLProject/Resources/Cambridge_Listings1.csv"
cambridge_listings = pd.read_csv(cambridge_path_listings)
cambridge_listings.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0   8521   https://www.airbnb.com/rooms/8521  20191126082128   2019-11-26
# 1  11169  https://www.airbnb.com/rooms/11169  20191126082128   2019-11-26
# 2  11945  https://www.airbnb.com/rooms/11945  20191126082128   2019-11-26
# 3  19581  https://www.airbnb.com/rooms/19581  20191126082128   2019-11-26
# 4  22006  https://www.airbnb.com/rooms/22006  20191126082128   2019-11-26
#
#                                                 name  \
# 0  SunsplashedSerenity near Harvard $1300/wk flex...
# 1    Lovely Studio Room: Thu-Mons Near Universities!
# 2                   Near Harvard: Safe & Lovely Room
# 3                           Furnished suite, Windsor
# 4                   B & B near Harvard's Quad Houses
#
#                                              summary  \
# 0  An elegant, sun-splashed, 2 bedroom (+2offices...
# 1  Large sunny room which comfortably fits a coup...
# 2  Room next to kitchen and living room in wonder...
# 3  Welcome to Area IV! We are located, convenient...
# 4  Two comfortable guest rooms in quiet, tree-fil...
#
#                                                space  \
# 0  An elegant, sun-splashed, 2+ bedroom apartment...
# 1  We have a peaceful, large, sunny room w/ attac...
# 2  Quiet peaceful room w/shared marble bath, wifi...
# 3  Furnished suite at the Windsor Inn, Cambridge....
# 4  Comfortable, convenient B&B at the north end o...
#
#                                          description experiences_offered  \
# 0  An elegant, sun-splashed, 2 bedroom (+2offices...                none
# 1  Large sunny room which comfortably fits a coup...                none
# 2  Room next to kitchen and living room in wonder...                none
# 3  Welcome to Area IV! We are located, convenient...                none
# 4  Two comfortable guest rooms in quiet, tree-fil...                none
#
#                                neighborhood_overview  ... instant_bookable  \
# 0  Huron Village is known for its charm.  We have...  ...                f
# 1  The neighborhood is quiet and friendly and our...  ...                f
# 2  Amazing neighborhood: Quiet yet close walk to ...  ...                f
# 3                                                NaN  ...                f
# 4  We're in a beautiful neighborhood, with nearby...  ...                f
#
#   is_business_travel_ready          cancellation_policy  \
# 0                        f  strict_14_with_grace_period
# 1                        f  strict_14_with_grace_period
# 2                        f  strict_14_with_grace_period
# 3                        f  strict_14_with_grace_period
# 4                        f                     moderate
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             f                                f
# 1                             t                                t
# 2                             t                                t
# 3                             f                                f
# 4                             f                                f
#
#    calculated_host_listings_count  \
# 0                               3
# 1                               4
# 2                               4
# 3                               3
# 4                               1
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            3
# 1                                            1
# 2                                            1
# 3                                            0
# 4                                            0
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            3
# 2                                            3
# 3                                            3
# 4                                            1
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0               0.26
# 1                                            0               1.22
# 2                                            0               0.27
# 3                                            0               0.05
# 4                                            0               0.89
#
# [5 rows x 106 columns]

# %%
# Cambridge Reviews -> CSV file
cambridge_path_reviews = "../ETLProject/Resources/Cambridge_Reviews.csv"
cambridge_reviews = pd.read_csv(cambridge_path_reviews)
cambridge_reviews.head()
# Out:
#    listing_id        id        date  reviewer_id reviewer_name  \
# 0        8521      6009  2009-07-23        25629          Mara
# 1        8521      6386  2009-07-30        26357     Stephanie
# 2        8521   6910163  2013-08-30      5747319       Lynette
# 3        8521  37307811  2015-07-06     27670573        Salina
# 4        8521  38475589  2015-07-16     10811805        Benoni
#
#                                             comments
# 0  This is a fabulous apartment!  Great neighborh...
# 1  Wonderful host and hostess, great home, locati...
# 2  We had a delightful 2 week stay in Cambridge. ...
# 3  We had a great time during our short stay in C...
# 4  Janet's place is as beautiful as portrayed. Ni...

# %% [markdown]
# ### Data Exploration

# %%
# Data Types - Listings
cambridge_listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1277 entries, 0 to 1276
# Columns: 106 entries, id to reviews_per_month
# dtypes: float64(22), int64(22), object(62)
# memory usage: 1.0+ MB

# %%
# Looking for Missing Values --> Listings
cambridge_listings.isnull().sum()
# Out:
# id                                                 0
# listing_url                                        0
# scrape_id                                          0
# last_scraped                                       0
# name                                               0
# summary                                           29
# space                                            263
# description                                       10
# experiences_offered                                0
# neighborhood_overview                            339
# notes                                            623
# transit                                          339
# access                                           506
# interaction                                      435
# house_rules                                      430
# thumbnail_url                                   1277
# medium_url                                      1277
# picture_url                                        0
# xl_picture_url                                  1277
# host_id                                            0
# host_url                                           0
# host_name                                          1
# host_since                                         1
# host_location                                      5
# host_about                                       434
# host_response_time                               184
# host_response_rate                               184
# host_acceptance_rate                            1277
# host_is_superhost                                  1
# host_thumbnail_url                                 1
#                                                 ...
# has_availability                                   0
# availability_30                                    0
# availability_60                                    0
# availability_90                                    0
# availability_365                                   0
# calendar_last_scraped                              0
# number_of_reviews                                  0
# number_of_reviews_ltm                              0
# first_review                                     178
# last_review                                      178
# review_scores_rating                             190
# review_scores_accuracy                           190
# review_scores_cleanliness                        190
# review_scores_checkin                            190
# review_scores_communication                      190
# review_scores_location                           190
# review_scores_value                              190
# requires_license                                   0
# license                                         1182
# jurisdiction_names                                 0
# instant_bookable                                   0
# is_business_travel_ready                           0
# cancellation_policy                                0
# require_guest_profile_picture                      0
# require_guest_phone_verification                   0
# calculated_host_listings_count                     0
# calculated_host_listings_count_entire_homes        0
# calculated_host_listings_count_private_rooms       0
# calculated_host_listings_count_shared_rooms        0
# reviews_per_month                                178
# Length: 106, dtype: int64

# %%
# Data Types - Reviews
cambridge_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64199 entries, 0 to 64198
# Data columns (total 6 columns):
# listing_id       64199 non-null int64
# id               64199 non-null int64
# date             64199 non-null object
# reviewer_id      64199 non-null int64
# reviewer_name    64197 non-null object
# comments         64169 non-null object
# dtypes: int64(3), object(3)
# memory usage: 2.9+ MB

# %%
# Looking for Missing Values --> Reviews
cambridge_reviews.isnull().sum()
# Out:
# listing_id        0
# id                0
# date              0
# reviewer_id       0
# reviewer_name     2
# comments         30
# dtype: int64

# %% [markdown]
# ### Data Clean-Up Process

# %%
# Data Frame 
listings_locations_df = cambridge_listings[['id', 'city', 'state','zipcode','latitude','longitude']].copy()
listing_details_df = cambridge_listings[['id', 'name', 'summary', 'property_type','bathrooms','bedrooms', 'beds']].copy()
Url_df = cambridge_listings[['id', 'listing_url', 'picture_url']].copy()
hosts_df = cambridge_listings[['id', 'host_id', 'host_url','host_name','host_since','host_location','host_response_rate']].copy()
cambridge_reviews_df = cambridge_reviews[['listing_id','id','date','reviewer_id','reviewer_name','comments']]

# %%
#Strips \"%\" from host_response_rate and converts to a float value (\"100%\" to \"1.0\")\n",
hosts_df['host_response_rate'] = hosts_df['host_response_rate'].str.rstrip('%').astype('float') / 100.0

# %%
# Preview Listing Locations
listings_locations_df.head()
# Out:
#       id       city state zipcode  latitude  longitude
# 0   8521  Cambridge    MA   02138  42.38329  -71.13617
# 1  11169  Cambridge    MA   02140  42.39469  -71.13223
# 2  11945  Cambridge    MA   02140  42.39454  -71.13431
# 3  19581  Cambridge    MA   02139  42.36276  -71.09765
# 4  22006  Cambridge    MA   02140  42.38670  -71.12387

# %%
# Preview Listing Details
listing_details_df.head()
# Out:
#       id                                               name  \
# 0   8521  SunsplashedSerenity near Harvard $1300/wk flex...
# 1  11169    Lovely Studio Room: Thu-Mons Near Universities!
# 2  11945                   Near Harvard: Safe & Lovely Room
# 3  19581                           Furnished suite, Windsor
# 4  22006                   B & B near Harvard's Quad Houses
#
#                                              summary      property_type  \
# 0  An elegant, sun-splashed, 2 bedroom (+2offices...          Apartment
# 1  Large sunny room which comfortably fits a coup...              House
# 2  Room next to kitchen and living room in wonder...        Condominium
# 3  Welcome to Area IV! We are located, convenient...  Bed and breakfast
# 4  Two comfortable guest rooms in quiet, tree-fil...              House
#
#    bathrooms  bedrooms  beds
# 0        1.0         2   2.0
# 1        1.0         1   1.0
# 2        1.0         1   1.0
# 3        1.0         1   1.0
# 4        2.5         1   1.0

# %%
# Preview Url
Url_df.head()
# Out:
#       id                         listing_url  \
# 0   8521   https://www.airbnb.com/rooms/8521
# 1  11169  https://www.airbnb.com/rooms/11169
# 2  11945  https://www.airbnb.com/rooms/11945
# 3  19581  https://www.airbnb.com/rooms/19581
# 4  22006  https://www.airbnb.com/rooms/22006
#
#                                          picture_url
# 0  https://a0.muscache.com/im/pictures/30536/072e...
# 1  https://a0.muscache.com/im/pictures/75383179/7...
# 2  https://a0.muscache.com/im/pictures/88bf993e-1...
# 3  https://a0.muscache.com/im/pictures/188f1b4b-f...
# 4  https://a0.muscache.com/im/pictures/10277743/5...

# %%
# Preview Host Info
hosts_df.head()
# Out:
#       id  host_id                                  host_url       host_name  \
# 0   8521   306681  https://www.airbnb.com/users/show/306681           Janet
# 1  11169    40965   https://www.airbnb.com/users/show/40965           Mazzy
# 2  11945    40965   https://www.airbnb.com/users/show/40965           Mazzy
# 3  19581    74249   https://www.airbnb.com/users/show/74249  Marc And Patty
# 4  22006    84280   https://www.airbnb.com/users/show/84280            Blue
#
#    host_since                            host_location  host_response_rate
# 0  2010-12-01  Cambridge, Massachusetts, United States                 1.0
# 1  2009-09-24  Cambridge, Massachusetts, United States                 1.0
# 2  2009-09-24  Cambridge, Massachusetts, United States                 1.0
# 3  2010-01-27  Cambridge, Massachusetts, United States                 1.0
# 4  2010-02-22  Cambridge, Massachusetts, United States                 1.0

# %%
# Preview Host Info
hosts_df.head()
# Out:
#       id  host_id                                  host_url       host_name  \
# 0   8521   306681  https://www.airbnb.com/users/show/306681           Janet
# 1  11169    40965   https://www.airbnb.com/users/show/40965           Mazzy
# 2  11945    40965   https://www.airbnb.com/users/show/40965           Mazzy
# 3  19581    74249   https://www.airbnb.com/users/show/74249  Marc And Patty
# 4  22006    84280   https://www.airbnb.com/users/show/84280            Blue
#
#    host_since                            host_location  host_response_rate
# 0  2010-12-01  Cambridge, Massachusetts, United States                 1.0
# 1  2009-09-24  Cambridge, Massachusetts, United States                 1.0
# 2  2009-09-24  Cambridge, Massachusetts, United States                 1.0
# 3  2010-01-27  Cambridge, Massachusetts, United States                 1.0
# 4  2010-02-22  Cambridge, Massachusetts, United States                 1.0

# %% [markdown]
# ### Database Process

# %%
# Connect to local database
engine = create_engine(f'postgresql://postgres:{password}@localhost:5432/Airbnb')

# %%
# Check for table
engine.table_names()
# Out:
# ['hosts', 'listings_locations', 'listings_details', 'url']

# %%
# Use pandas to load csv converted DataFrame into database
listings_locations_df.to_sql(name='listings_locations', con=engine,if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1223                     self.dialect.do_executemany(
# -> 1224                         cursor, statement, parameters, context
#    1225                     )
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     772         else:
# --> 773             cursor.executemany(statement, parameters)
#     774
#
# UniqueViolation: duplicate key value violates unique constraint "listings_locations_pkey"
# DETAIL:  Key (id)=(8521) already exists.
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-18-f6a14d854ca8> in <module>
#       1 # Use pandas to load csv converted DataFrame into database
# ----> 2 listings_locations_df.to_sql(name='listings_locations', con=engine,if_exists='append', index=False)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2529         sql.to_sql(self, name, con, schema=schema, if_exists=if_exists,
#    2530                    index=index, index_label=index_label, chunksize=chunksize,
# -> 2531                    dtype=dtype, method=method)
#    2532
#    2533     def to_pickle(self, path, compression='infer',
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     458     pandas_sql.to_sql(frame, name, if_exists=if_exists, index=index,
#     459                       index_label=index_label, schema=schema,
# --> 460                       chunksize=chunksize, dtype=dtype, method=method)
#     461
#     462
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1172                          schema=schema, dtype=dtype)
#    1173         table.create()
# -> 1174         table.insert(chunksize, method=method)
#    1175         if (not name.isdigit() and not name.islower()):
#    1176             # check for potentially case sensitivity issues (GH7815)
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     684
#     685                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 686                 exec_insert(conn, keys, chunk_iter)
#     687
#     688     def _query_iterator(self, result, chunksize, columns, coerce_float=True,
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     597         """
#     598         data = [dict(zip(keys, row)) for row in data_iter]
# --> 599         conn.execute(self.table.insert(), data)
#     600
#     601     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#     986             raise exc.ObjectNotExecutableError(object_)
#     987         else:
# --> 988             return meth(self, multiparams, params)
#     989
#     990     def _execute_function(self, func, multiparams, params):
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     285     def _execute_on_connection(self, connection, multiparams, params):
#     286         if self.supports_execution:
# --> 287             return connection._execute_clauseelement(self, multiparams, params)
#     288         else:
#     289             raise exc.ObjectNotExecutableError(self)
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1105             distilled_params,
#    1106             compiled_sql,
# -> 1107             distilled_params,
#    1108         )
#    1109         if self._has_events or self.engine._has_events:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1246         except BaseException as e:
#    1247             self._handle_dbapi_exception(
# -> 1248                 e, statement, parameters, cursor, context
#    1249             )
#    1250
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1464                 util.raise_from_cause(newraise, exc_info)
#    1465             elif should_wrap:
# -> 1466                 util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1467             else:
#    1468                 util.reraise(*exc_info)
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     397     exc_type, exc_value, exc_tb = exc_info
#     398     cause = exc_value if exc_value is not exception else None
# --> 399     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     400
#     401
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     151             value.__cause__ = cause
#     152         if value.__traceback__ is not tb:
# --> 153             raise value.with_traceback(tb)
#     154         raise value
#     155
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1222                 if not evt_handled:
#    1223                     self.dialect.do_executemany(
# -> 1224                         cursor, statement, parameters, context
#    1225                     )
#    1226             elif not parameters and context.no_parameters:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     771             extras.execute_batch(cursor, statement, parameters)
#     772         else:
# --> 773             cursor.executemany(statement, parameters)
#     774
#     775     @util.memoized_instancemethod
#
# IntegrityError: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "listings_locations_pkey"
# DETAIL:  Key (id)=(8521) already exists.
#
# [SQL: INSERT INTO listings_locations (id, city, state, zipcode, latitude, longitude) VALUES (%(id)s, %(city)s, %(state)s, %(zipcode)s, %(latitude)s, %(longitude)s)]
# [parameters: ({'id': 8521, 'city': 'Cambridge', 'state': 'MA', 'zipcode': '02138', 'latitude': 42.38329, 'longitude': -71.13616999999999}, {'id': 11169, 'city': 'Cambridge', 'state': 'MA', 'zipcode': '02140', 'latitude': 42.394690000000004, 'longitude': -71.13223}, {'id': 11945, 'city': 'Cambridge', 'state': 'MA', 'zipcode': '02140', 'latitude': 42.39454, 'longitude': -71.13431}, {'id': 19581, 'city': 'Cambridge', 'state': 'MA', 'zipcode': '02139', 'latitude': 42.362759999999994, 'longitude': -71.09765}, {'id': 22006, 'city': 'Cambridge', 'state': 'MA', 'zipcode': '02140', 'latitude': 42.3867, 'longitude': -71.12387}, {'id': 24063, 'city': 'Cambridge', 'state': 'MA', 'zipcode': '02138', 'latitude': 42.376059999999995, 'longitude': -71.14041}, {'id': 27498, 'city': 'Cambridge', 'state': 'MA', 'zipcode': '02139', 'latitude': 42.36381, 'longitude': -71.09754000000001}, {'id': 79762, 'city': 'Cambridge', 'state': 'MA', 'zipcode': '02139', 'latitude': 42.37057, 'longitude': -71.10029}  ... displaying 10 of 1277 total bound parameter sets ...  {'id': 40092989, 'city': 'Cambridge', 'state': 'MA', 'zipcode': '02141', 'latitude': 42.37108, 'longitude': -71.08634}, {'id': 40327298, 'city': 'Brookline', 'state': 'MA', 'zipcode': '02446', 'latitude': 42.34875, 'longitude': -71.10710999999999})]
# (Background on this error at: http://sqlalche.me/e/gkpj)

# %%
listing_details_df.to_sql(name='listings_details', con=engine,if_exists='append', index=False)

# %%
Url_df.to_sql(name='url', con=engine,if_exists='append', index=False)

# %%
hosts_df.to_sql(name='hosts', con=engine,if_exists='append', index=False)

# %%
cambridge_reviews_df.to_sql(name='reviews', con=engine,if_exists='append', index=False)

# %% [markdown]
# ### Queries

# %%
# Hosts
pd.read_sql_query('select * from hosts', con=engine)

# %%
# Listings Locations
pd.read_sql_query('select * from listings_locations', con=engine)
# Out:
#             id           city state   zipcode  latitude  longitude
# 0         8521      Cambridge    MA     02138  42.38329  -71.13617
# 1        11169      Cambridge    MA     02140  42.39469  -71.13223
# 2        11945      Cambridge    MA     02140  42.39454  -71.13431
# 3        19581      Cambridge    MA     02139  42.36276  -71.09765
# 4        22006      Cambridge    MA     02140  42.38670  -71.12387
# 5        24063      Cambridge    MA     02138  42.37606  -71.14041
# 6        27498      Cambridge    MA     02139  42.36381  -71.09754
# 7        79762      Cambridge    MA     02139  42.37057  -71.10029
# 8       106474      Cambridge    MA     02139  42.36270  -71.09645
# 9       108898      Cambridge    MA     02138  42.38377  -71.13543
# 10      219471      Cambridge    MA     02139  42.36109  -71.10425
# 11      231115      Cambridge    MA     02139  42.36680  -71.10673
# 12      257645      Cambridge    MA     02138  42.38375  -71.12955
# 13      280304      Cambridge    MA     02138  42.37083  -71.11402
# 14      314465      Cambridge    MA     02139  42.35965  -71.10556
# 15      321847      Cambridge    MA     02139  42.36498  -71.09869
# 16      326170      Cambridge    MA     02138  42.38247  -71.11403
# 17      365220     Somerville    MA     02144  42.38817  -71.12898
# 18      405144  Mid-Cambridge    MA     02138  42.37125  -71.11105
# 19      405548  Huron Village    MA     02138  42.38258  -71.13710
# 20      445407  Mid-Cambridge    MA     02141  42.37363  -71.08909
# 21      459074      Cambridge    MA     02139  42.36291  -71.10435
# 22      461525      Cambridge    MA     02138  42.37273  -71.11168
# 23      464471      Cambridge    MA     02139  42.37317  -71.09743
# 24      577384      Cambridge    MA     02139  42.36598  -71.09909
# 25      715532      Cambridge    MA     02140  42.39420  -71.13202
# 26      742574      Cambridge    MA     02139  42.36486  -71.10328
# 27      798213      Cambridge    MA     02140  42.40135  -71.13569
# 28      810461      Cambridge    MA     02139  42.37047  -71.09781
# 29      860634      Cambridge    MA     02138  42.38391  -71.11449
# ...        ...            ...   ...       ...       ...        ...
# 1247  39728795      Cambridge    MA     02140  42.39191  -71.13079
# 1248  39747422      Cambridge    MA  MA 02139  42.36380  -71.09909
# 1249  39747612      Cambridge    MA  MA 02139  42.36433  -71.10041
# 1250  39756220      Cambridge    MA     02139  42.36224  -71.10828
# 1251  39756346      Cambridge    MA     02139  42.36162  -71.11003
# 1252  39756515      Cambridge    MA     02139  42.36360  -71.10855
# 1253  39756601      Cambridge    MA     02139  42.36296  -71.10894
# 1254  39778340     Somerville    MA     02144  42.38616  -71.11619
# 1255  39787306      Cambridge    MA     02139  42.36861  -71.09601
# 1256  39815404      Cambridge    MA     02139  42.36562  -71.11410
# 1257  39856289     Somerville    MA     02144  42.38774  -71.11745
# 1258  39864033     Cambridge     MA     02141  42.36922  -71.09533
# 1259  39864255      Cambridge    MA     02141  42.37140  -71.07307
# 1260  39866038      Cambridge    MA     02141  42.37348  -71.09045
# 1261  39895736      Cambridge    MA      None  42.36456  -71.10253
# 1262  39908171      Cambridge    MA  MA 02140  42.38550  -71.11596
# 1263  39908320      Cambridge    MA  MA 02140  42.38438  -71.11655
# 1264  39908347      Cambridge    MA  MA 02140  42.38508  -71.11613
# 1265  39908417      Cambridge    MA  MA 02139  42.36998  -71.10803
# 1266  39918050      Cambridge    MA      None  42.36603  -71.10346
# 1267  39918227      Cambridge    MA      None  42.36669  -71.10351
# 1268  39984608      Cambridge    MA     02139  42.35859  -71.10966
# 1269  40007328     Somerville    MA     02143  42.37820  -71.09452
# 1270  40064240      Cambridge    MA     02138  42.37732  -71.14971
# 1271  40064507      Cambridge    MA     02138  42.37678  -71.14914
# 1272  40064688      Cambridge    MA     02142  42.36452  -71.07888
# 1273  40080356      Cambridge    MA     02139  42.36254  -71.11145
# 1274  40092525      Cambridge    MA     02141  42.37060  -71.08737
# 1275  40092989      Cambridge    MA     02141  42.37108  -71.08634
# 1276  40327298      Brookline    MA     02446  42.34875  -71.10711
#
# [1277 rows x 6 columns]

# %%
# Listings Details
pd.read_sql_query('select * from listings_details', con=engine)
# Out:
#             id                                               name  \
# 0         8521  SunsplashedSerenity near Harvard $1300/wk flex...
# 1        11169    Lovely Studio Room: Thu-Mons Near Universities!
# 2        11945                   Near Harvard: Safe & Lovely Room
# 3        19581                           Furnished suite, Windsor
# 4        22006                   B & B near Harvard's Quad Houses
# 5        24063                        Riverbend Bed and Breakfast
# 6        27498                    Furnished suite 2 @ the Windsor
# 7        79762                  Cambridge Getaway @ Harvard & MIT
# 8       106474                large furnished suite in Central sq
# 9       108898      "The Treehouse":  Elegant living near Harvard
# 7             1         2   2.0
# 8             1         1   1.0
# 9             1         1   1.0
# 10            1         1   1.0
# 11            1         1   1.0
# 12            1         1   1.0
# 13            1         1   1.0
# 14            3         3   6.0
# 15            2         2   4.0
# 16            1         1   1.0
# 17            1         1   1.0
# 18            1         1   1.0
# 19            1         2   4.0
# 20            2         4   6.0
# 21            1         1   0.0
# 22            1         2   0.0
# 23            1         1   1.0
# 24            1         1   1.0
# 25            1         1   1.0
# 26            1         1   2.0
# 27            1         1   1.0
# 28            1         1   1.0
# 29            1         1   1.0
# ...         ...       ...   ...
# 1247          2         2   3.0
# 1248          2         2   2.0
# 1249          1         1   1.0
# 1250          1         1   1.0
# 1251          1         1   1.0
# 1252          1         1   1.0
# 1253          1         3   3.0
# 1254          1         1   1.0
# 1255          1         0   2.0
# 1256          1         2   2.0
# 1257          1         1   1.0
# 1258          2         1   1.0
# 1259          1         1   1.0
# 1260          1         1   1.0
# 1261          1         2   2.0
# 1262          1         1   1.0
# 1263          1         1   1.0
# 1264          1         1   1.0
# 1265          1         1   1.0
# 1266          1         1   1.0
# 1267          1         2   2.0
# 1268          1         1   0.0
# 1269          1         1   2.0
# 1270          1         1   NaN
# 1271          1         1   1.0
# 1272          1         1   3.0
# 1273          2         2   2.0
# 1274          1         1   NaN
# 1275          1         1   1.0
# 1276          1         2   3.0
#
# [1277 rows x 7 columns]

# %%
# Url
pd.read_sql_query('select * from url', con=engine)
# Out:
#             id                            listing_url  \
# 0         8521      https://www.airbnb.com/rooms/8521
# 1        11169     https://www.airbnb.com/rooms/11169
# 2        11945     https://www.airbnb.com/rooms/11945
# 3        19581     https://www.airbnb.com/rooms/19581
# 4        22006     https://www.airbnb.com/rooms/22006
# 5        24063     https://www.airbnb.com/rooms/24063
# 6        27498     https://www.airbnb.com/rooms/27498
# 7        79762     https://www.airbnb.com/rooms/79762
# 8       106474    https://www.airbnb.com/rooms/106474
# 9       108898    https://www.airbnb.com/rooms/108898
# 10      219471    https://www.airbnb.com/rooms/219471
# 11      231115    https://www.airbnb.com/rooms/231115
# 12      257645    https://www.airbnb.com/rooms/257645
# 13      280304    https://www.airbnb.com/rooms/280304
# 14      314465    https://www.airbnb.com/rooms/314465
# 15      321847    https://www.airbnb.com/rooms/321847
# 16      326170    https://www.airbnb.com/rooms/326170
# 17      365220    https://www.airbnb.com/rooms/365220
# 18      405144    https://www.airbnb.com/rooms/405144
# 19      405548    https://www.airbnb.com/rooms/405548
# 20      445407    https://www.airbnb.com/rooms/445407
# 21      459074    https://www.airbnb.com/rooms/459074
# 22      461525    https://www.airbnb.com/rooms/461525
# 23      464471    https://www.airbnb.com/rooms/464471
# 24      577384    https://www.airbnb.com/rooms/577384
# 25      715532    https://www.airbnb.com/rooms/715532
# 26      742574    https://www.airbnb.com/rooms/742574
# 27      798213    https://www.airbnb.com/rooms/798213
# 28      810461    https://www.airbnb.com/rooms/810461
# 29      860634    https://www.airbnb.com/rooms/860634
# ...        ...                                    ...
# 1247  39728795  https://www.airbnb.com/rooms/39728795
# 1248  39747422  https://www.airbnb.com/rooms/39747422
# 1249  39747612  https://www.airbnb.com/rooms/39747612
 9419684, 'https://www.airbnb.com/users/show/9419684', 'Mike', '2013-10-14', 'New York, New York, United States', '98%')
# (22339138, 9419684, 'https://www.airbnb.com/users/show/9419684', 'Mike', '2013-10-14', 'New York, New York, United States', '98%')
# (22339678, 9419684, 'https://www.airbnb.com/users/show/9419684', 'Mike', '2013-10-14', 'New York, New York, United States', '98%')
# (22339933, 9419684, 'https://www.airbnb.com/users/show/9419684', 'Mike', '2013-10-14', 'New York, New York, United States', '98%')
# (30386484, 107434423, 'https://www.airbnb.com/users/show/107434423', 'Blueground', '2016-12-16', 'New York, New York, United States', '96%')
# (30389876, 107434423, 'https://www.airbnb.com/users/show/107434423', 'Blueground', '2016-12-16', 'New York, New York, United States', '96%')
# (30389899, 107434423, 'https://www.airbnb.com/users/show/107434423', 'Blueground', '2016-12-16', 'New York, New York, United States', '96%')
# (30389924, 107434423, 'https://www.airbnb.com/users/show/107434423', 'Blueground', '2016-12-16', 'New York, New York, United States', '96%')
# (30390003, 107434423, 'https://www.airbnb.com/users/show/107434423', 'Blueground', '2016-12-16', 'New York, New York, United States', '96%')
# (30390533, 107434423, 'https://www.airbnb.com/users/show/107434423', 'Blueground', '2016-12-16', 'New York, New York, United States', '96%')
# (30397057, 107434423, 'https://www.airbnb.com/users/show/107434423', 'Blueground', '2016-12-16', 'New York, New York, United States', '96%')
# (30397111, 107434423, 'https://www.airbnb.com/users/show/107434423', 'Blueground', '2016-12-16', 'New York, New York, United States', '96%')
# (30489683, 107434423, 'https://www.airbnb.com/users/show/107434423', 'Blueground', '2016-12-16', 'New York, New York, United States', '96%')
# (32324379, 107434423, 'https://www.airbnb.com/users/show/107434423', 'Blueground', '2016-12-16', 'New York, New York, United States', '96%')
# (32783224, 3613138, 'https://www.airbnb.com/users/show/3613138', 'Eszter', '2012-09-19', 'New York, New York, United States', None)
# (33028188, 107434423, 'https://www.airbnb.com/users/show/107434423', 'Blueground', '2016-12-16', 'New York, New York, United States', '96%')
# (33183552, 107434423, 'https://www.airbnb.com/users/show/107434423', 'Blueground', '2016-12-16', 'New York, New York, United States', '96%')
# (33341290, 107434423, 'https://www.airbnb.com/users/show/107434423', 'Blueground', '2016-12-16', 'New York, New York, United States', '96%')
# (33341404, 107434423, 'https://www.airbnb.com/users/show/107434423', 'Blueground', '2016-12-16', 'New York, New York, United States', '96%')
# (33551653, 107434423, 'https://www.airbnb.com/users/show/107434423', 'Blueground', '2016-12-16', 'New York, New York, United States', '96%')
# (33596731, 107434423, 'https://www.airbnb.com/users/show/107434423', 'Blueground', '2016-12-16', 'New York, New York, United States', '96%')
# (33787948, 107434423, 'https://www.airbnb.com/users/show/107434423', 'Blueground', '2016-12-16', 'New York, New York, United States', '96%')
# (34132996, 107434423, 'https://www.airbnb.com/users/show/107434423', 'Blueground', '2016-12-16', 'New York, New York, United States', '96%')
# (35786321, 76519427, 'https://www.airbnb.com/users/show/76519427', 'Erin', '2016-06-08', 'New York, New York, United States', '100%')
# (35821512, 76519427, 'https://www.airbnb.com/users/show/76519427', 'Erin', '2016-06-08', 'New York, New York, United States', '100%')
# (36402816, 107434423, 'https://www.airbnb.com/users/show/107434423', 'Blueground', '2016-12-16', 'New York, New York, United States', '96%')
# (37142306, 107434423, 'https://www.airbnb.com/users/show/107434423', 'Blueground', '2016-12-16', 'New York, New York, United States', '96%')
# (37696869, 107434423, 'https://www.airbnb.com/users/show/107434423', 'Blueground', '2016-12-16', 'New York, New York, United States', '96%')
# (37814939, 255433680, 'https://www.airbnb.com/users/show/255433680', 'Jiaming', '2019-04-12', 'New York, New York, United States', '100%')
# (37975180, 174201783, 'https://www.airbnb.com/users/show/174201783', 'Alam', '2018-02-19', 'New York, New York, United States', '100%')
# (38015454, 107434423, 'https://www.airbnb.com/users/show/107434423', 'Blueground', '2016-12-16', 'New York, New York, United States', '96%')
# (38015563, 107434423, 'https://www.airbnb.com/users/show/107434423', 'Blueground', '2016-12-16', 'New York, New York, United States', '96%')
# (38404696, 186970542, 'https://www.airbnb.com/users/show/186970542', 'Jasmine', '2018-04-29', 'New York, New York, United States', '100%')
# (38617180, 145573505, 'https://www.airbnb.com/users/show/145573505', 'Jasmine', '2017-08-11', 'New York, New York, United States', '100%')
# (38656707, 107434423, 'https://www.airbnb.com/users/show/107434423', 'Blueground', '2016-12-16', 'New York, New York, United States', '96%')
# (38838410, 107434423, 'https://www.airbnb.com/users/show/107434423', 'Blueground', '2016-12-16', 'New York, New York, United States', '96%')
# (38838468, 107434423, 'https://www.airbnb.com/users/show/107434423', 'Blueground', '2016-12-16', 'New York, New York, United States', '96%')
# (38844088, 161514654, 'https://www.airbnb.com/users/show/161514654', 'Hafou', '2017-12-05', 'New York, New York, United States', '100%')
# (38915459, 107434423, 'https://www.airbnb.com/users/show/107434423', 'Blueground', '2016-12-16', 'New York, New York, United States', '96%')
# (38925934, 107434423, 'https://www.airbnb.com/users/show/107434423', 'Blueground', '2016-12-16', 'New York, New York, United States', '96%')
# (39116466, 246017238, 'https://www.airbnb.com/users/show/246017238', 'Shuting', '2019-02-28', 'New York, New York, United States', '100%')
# (39239952, 107434423, 'https://www.airbnb.com/users/show/107434423', 'Blueground', '2016-12-16', 'New York, New York, United States', '96%')
# (39747422, 107434423, 'https://www.airbnb.com/users/show/107434423', 'Blueground', '2016-12-16', 'New York, New York, United States', '96%')
# (39747612, 107434423, 'https://www.airbnb.com/users/show/107434423', 'Blueground', '2016-12-16', 'New York, New York, United States', '96%')
# (39866038, 17936854, 'https://www.airbnb.com/users/show/17936854', 'Alexander', '2014-07-10', 'New York, New York, United States', '100%')
# (39908171, 107434423, 'https://www.airbnb.com/users/show/107434423', 'Blueground', '2016-12-16', 'New York, New York, United States', '96%')
# (39908320, 107434423, 'https://www.airbnb.com/users/show/107434423', 'Blueground', '2016-12-16', 'New York, New York, United States', '96%')
# (39908347, 107434423, 'https://www.airbnb.com/users/show/107434423', 'Blueground', '2016-12-16', 'New York, New York, United States', '96%')
# (39908417, 107434423, 'https://www.airbnb.com/users/show/107434423', 'Blueground', '2016-12-16', 'New York, New York, United States', '96%')

# %%
# Property --> Bathrooms >= 4
data = engine.execute("SELECT id, name, property_type FROM listings_details WHERE bathrooms >= 4;")
for record in data:
    print(record)
# Out:
# (4242801, 'BIG QUEEN ROOM HARVARD MIT MGH BOSTON', 'House')
# (19847550, '*New Construction Luxury Kendall Square Townhouse*', 'Townhouse')
# (32573946, 'Harvard/Lesley/Tufts/MIT full 5-Br 3.5 bath house', 'House')
# (34806032, 'NEW 4Bed House @ Harvard Sq--Parking+Private Yard!', 'House')
# (35187780, 'Franklin Blue House', 'House')
# (36197065, "Historic Richardson's Row In Harvard Square", 'Townhouse')

# %%
# Join --> listing locations and listings_details 
query = pd.read_sql_query("""
select listings_locations.id, listings_locations.city, listings_details.name
from listings_locations 
inner join listings_details
on listings_locations.id = listings_details.id;
""",
con=engine)

query.head()
# Out:
#       id       city                                               name
# 0   8521  Cambridge  SunsplashedSerenity near Harvard $1300/wk flex...
# 1  11169  Cambridge    Lovely Studio Room: Thu-Mons Near Universities!
# 2  11945  Cambridge                   Near Harvard: Safe & Lovely Room
# 3  19581  Cambridge                           Furnished suite, Windsor
# 4  22006  Cambridge                   B & B near Harvard's Quad Houses
