# %%
import gzip
import csv
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
sns.set_style("whitegrid")
sns.set(font_scale=1.5)

# %%
# Cambridge Listing --> CSV file
cambridge_path_listings = "..ETLProject/Resources/Cambridge_Listings.csv"
cambridge_listings = pd.read_csv(cambridge_path_listings)
cambridge_listings.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-8d8ae2fe3e13> in <module>
#       1 # Cambridge Listing --> CSV file
#       2 cambridge_path_listings = "../Cambridge_Listings.csv"
# ----> 3 cambridge_listings = pd.read_csv(cambridge_path_listings)
#       4 cambridge_listings.head()
#
# ...

# %%
# Cambridge Reviews -> CSV file
cambridge_path_reviews = "C:/Users/maria/Desktop/DATA SCIENCE BOOTCAMP/PROJECTS/ETLProject/Resources/Cambridge_Reviews.csv"
cambridge_reviews = pd.read_csv(cambridge_path_reviews)
cambridge_reviews.head()
# Out:
#    listing_id        id        date  reviewer_id reviewer_name  \
# 0        8521      6009  2009-07-23        25629          Mara
# 1        8521      6386  2009-07-30        26357     Stephanie
# 2        8521   6910163  2013-08-30      5747319       Lynette
# 3        8521  37307811  2015-07-06     27670573        Salina
# 4        8521  38475589  2015-07-16     10811805        Benoni
#
#                                             comments
# 0  This is a fabulous apartment!  Great neighborh...
# 1  Wonderful host and hostess, great home, locati...
# 2  We had a delightful 2 week stay in Cambridge. ...
# 3  We had a great time during our short stay in C...
# 4  Janet's place is as beautiful as portrayed. Ni...

# %%
# Cambridge Neighborhoods --> geojson file
reviews_LA_path = "C:/Users/maria/Desktop/DATA SCIENCE BOOTCAMP/PROJECTS/Project 2_Group-4/Resources/reviews_LA.csv"
los_angeles_reviews = pd.read_csv(reviews_LA_path)
los_angeles_reviews.head()
# Out:
#    listing_id        date
# 0       30187  2010-10-18
# 1       30187  2011-03-21
# 2       30187  2016-06-13
# 3       30187  2016-07-19
# 4       30187  2017-05-23

# %%
#LA neighbourhoods
neighbourhoods_LA_path = "C:/Users/maria/Desktop/DATA SCIENCE BOOTCAMP/PROJECTS/Project 2_Group-4/Resources/neighbourhoods_LA.csv"
los_angeles_neighbourhoods = pd.read_csv(neighbourhoods_LA_path)
los_angeles_neighbourhoods.head()
# Out:
#    neighbourhood_group       neighbourhood
# 0                  NaN  1er Arrondissement
# 1                  NaN   2e Arrondissement
# 2                  NaN   3e Arrondissement
# 3                  NaN   4e Arrondissement
# 4                  NaN   5e Arrondissement

# %%
# NY Neighboardhoods -> GZfile

# %%
los_angeles_listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40125 entries, 0 to 40124
# Data columns (total 16 columns):
# id                                40125 non-null int64
# name                              40123 non-null object
# host_id                           40125 non-null int64
# host_name                         39690 non-null object
# neighbourhood_group               40125 non-null object
# neighbourhood                     40125 non-null object
# latitude                          40125 non-null float64
# longitude                         40125 non-null float64
# room_type                         40125 non-null object
# price                             40125 non-null int64
# minimum_nights                    40125 non-null int64
# number_of_reviews                 40125 non-null int64
# last_review                       31980 non-null object
# reviews_per_month                 31980 non-null float64
# calculated_host_listings_count    40125 non-null int64
# ...

# %%
# Looking for Null Values
los_angeles_listings.isnull().sum()
# Out:
# id                                   0
# name                                 2
# host_id                              0
# host_name                          435
# neighbourhood_group                  0
# neighbourhood                        0
# latitude                             0
# longitude                            0
# room_type                            0
# price                                0
# minimum_nights                       0
# number_of_reviews                    0
# last_review                       8145
# reviews_per_month                 8145
# calculated_host_listings_count       0
# availability_365                     0
# dtype: int64

# %%
los_angeles_listings.drop(["id", "host_name"], axis="columns", inplace=True)
los_angeles_listings.head()
# Out:
#                                                 name  host_id  \
# 0  Amazing bright elegant condo park front *UPGRA...      521
# 1                  Family perfect;Pool;Near Studios!      767
# 2  Mirrored Mini-Suite with Fireplace - W. Hollywood     3008
# 3                              Zen Life at the Beach     3041
# 4  *Upscale Professional Home with Beautiful Studio*     3207
#
#    neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0         Other Cities   Culver City  33.98209 -118.38494  Entire home/apt
# 1         Other Cities       Burbank  34.16562 -118.33458  Entire home/apt
# 2  City of Los Angeles     Hollywood  34.09768 -118.34602     Private room
# 3         Other Cities  Santa Monica  34.00475 -118.48127     Private room
# 4         Other Cities    Bellflower  33.87619 -118.11397  Entire home/apt
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# ...

# %%
# Visualizing the distribution for every "feature"
features = los_angeles_listings.hist(edgecolor="black", linewidth=1.2, figsize=(30, 30))

# %%
plt.figure(figsize=(100, 100))
sns.pairplot(los_angeles_listings, height=3, diag_kind="hist")

# %%
# We notice from the graphs that :

# latitude and longitude have a normal distribution, most of the hosts are concetrated in specific area.
# reviews_per_month has a lot of outlayers, because of the missing values
# availability_365 the most of the hosts are not available all the year.
# price most the host has a price under $1000

# %%
sns.catplot("neighbourhood_group", data=los_angeles_listings, kind="count", height=8)

# %%
sns.set(font_scale=1.5)
sns.catplot("room_type", data=los_angeles_listings, kind="count", height=8)

# %%
# Entire place
# Entire places are best if you're seeking a home away from home. With an entire place, you'll have the whole space to yourself. This usually includes a bedroom, a bathroom, a kitchen, and a separate, dedicated entrance. 

# Private rooms
# Private rooms are great for when you prefer a little privacy, and still value a local connection. When you book a private room, you'll have your own private room for sleeping and may share some spaces with others. You might need to walk through indoor spaces that another host or guest may occupy to get to your room.

# Shared rooms
# Shared rooms are for when you don't mind sharing a space with others. When you book a shared room, you'll be sleeping in a space that is shared with others and share the entire space with other people. Shared rooms are popular among flexible travelers looking for new friends and budget-friendly stays.

# %%
plt.style.use("fivethirtyeight")

data = los_angeles_listings.neighbourhood.value_counts()[:10]
plt.figure(figsize=(20, 8))
x = list(data.index)
y = list(data.values)
x.reverse()
y.reverse()

plt.title("Most Popular Neighbourhood")
plt.ylabel("Neighbourhood Area")
plt.xlabel("Number of guest Who host in this Area")

plt.barh(x, y)
# Out:
# <BarContainer object of 10 artists>

# %%
plt.figure(figsize=(12, 8))
plt.scatter(los_angeles_listings.longitude, los_angeles_listings.latitude, c=los_angeles_listings.availability_365, cmap='summer', edgecolor='black', linewidth=1, alpha=0.75)

cbar = plt.colorbar()
cbar.set_label('availability_365')

# %%
locations = los_angeles_listings[['longitude', 'latitude']]
weights = los_angeles_listings['availability_365']
fig = gmaps.figure()
fig.add_layer(gmaps.heatmap_layer(locations, weights=weights))
fig
# Out:
# ---------------------------------------------------------------------------
# InvalidPointException                     Traceback (most recent call last)
# <ipython-input-111-33026fc21f0f> in <module>
#       2 weights = los_angeles_listings['availability_365']
#       3 fig = gmaps.figure()
# ----> 4 fig.add_layer(gmaps.heatmap_layer(locations, weights=weights))
#       5 fig
#
# ~\Anaconda3\lib\site-packages\gmaps\heatmap.py in heatmap_layer(locations, weights, max_intensity, dissipating, point_radius, opacity, gradient)
#     267     )
#     268     if is_weighted:
# --> 269         return WeightedHeatmap(**widget_args)
#     270     else:
#     271         return Heatmap(**widget_args)
#
# ~\Anaconda3\lib\site-packages\ipywidgets\widgets\widget.py in __init__(self, **kwargs)
#     408         """Public constructor"""
#     409         self._model_id = kwargs.pop('model_id', None)
# --> 410         super(Widget, self).__init__(**kwargs)
#     411
# ...

# %%
print(f"Average of price per night : ${los_angeles_listings.price.mean():.2f}")
print(f"Maximum price per night : ${los_angeles_listings.price.max()}")
print(f"Minimum price per night : ${los_angeles_listings.price.min()}")
# Out:
# Average of price per night : $225.84
# Maximum price per night : $25000
# Minimum price per night : $0

# %%
# "Free houses"
los_angeles_listings[los_angeles_listings.price == 0]
# Out:
#                                            name    host_id  \
# 13381  **Quiet Room in Bixby Knolls** in LB, CA    4804681
# 13422        VENICE MODERN 3 BEDROOM BUNGALOW!!  128864237
# 16187  Private rooms +breakfast! #1      (1of2)  152107488
# 16286              Cozy 1 Bedroom in the Valley   31478582
# 24806        Adorable 2 bedroom, den, pool, w/d  106050725
#
#        neighbourhood_group    neighbourhood  latitude  longitude  \
# 13381         Other Cities       Long Beach  33.82912 -118.20102
# 13422         Other Cities      Culver City  33.99522 -118.43324
# 16187  City of Los Angeles   Harbor Gateway  33.86413 -118.29326
# 16286  City of Los Angeles         Van Nuys  34.19718 -118.44036
# 24806  City of Los Angeles  North Hollywood  34.16589 -118.35716
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 13381     Private room      0               1                 66  2019-12-03
# ...

# %%
# correlation matrix
sns.set(font_scale=3)
plt.figure(figsize=(30, 20))
sns.heatmap(los_angeles_listings.corr(), annot=True)
